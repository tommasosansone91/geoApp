# %%
import numpy as np

c = [44.8683931,9.2651729]



for i in range(32):
    print(i)
    print( str(c[1] + np.random.randn() * 0.01) + "," )
    print( "            " + str( c[0] + np.random.randn() * 0.01) )
# Out:
# 0
# 9.270681953844745,
#             44.85297239571794
# 1
# 9.258835506189937,
#             44.88284616084105
# 2
# 9.283641672028185,
#             44.87051099969884
# 3
# 9.253286706526827,
#             44.864610117702235
# 4
# 9.285133643751802,
#             44.85268637659046
# 5
# 9.263827885312638,
#             44.863820790022274
# 6
# 9.248048886344943,
#             44.883777444558575
# 7
# 9.256621187575949,
#             44.868817089471094
# 8
# 9.279500182122675,
#             44.86080525181927
# 9
# 9.282322083916434,
#             44.866507972236306
# 10
# 9.261751790014888,
#             44.85927530640128
# 11
# 9.254707717998146,
#             44.862576766165276
# 12
# 9.273710030143787,
#             44.865997908834444
# 13
# 9.259417355909244,
#             44.8629857016801
# 14
# 9.257928917298083,
#             44.86993284402846
# 15
# 9.27422857588893,
#             44.86975695035669
# 16
# 9.253083729707633,
#             44.87317411610709
# 17
# ...

# %%
np.random.randn() * 0.1
# Out:
# 0.02580962179911461
